# %%
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\paceh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
api_key = "fff1504690f81c1961f2634380bb0c2a59a6ebdc"
url = f"https://api.census.gov/data/2024/acs/acs1?get=NAME,B01001_001E,B18135_001E,B08128_010E,B24114_224E,B09010_002E,B08006_008E&for=county:*&in=state:37&descriptive=true&key={api_key}"

# %%
responce = requests.get(url)

# %%
data = responce.json()

# %%
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.head()
# Out:
#                                NAME       B01001_001E       B18135_001E  \
# 0              Geographic Area Name  Estimate!!Total:  Estimate!!Total:
# 1   Alamance County, North Carolina            183040            182153
# 2  Brunswick County, North Carolina            167112            165900
# 3   Buncombe County, North Carolina            279210            275574
# 4      Burke County, North Carolina             88545             86322
#
#                                B08128_010E  \
# 0  Estimate!!Total:!!Unpaid family workers
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
#
#                                          B24114_224E  \
# 0  Estimate!!Total:!!Healthcare diagnosing or tre...
# 1                                               None
# 2                                               None
# ...

# %% [markdown]
# Questions:
# - How do employment conditions, healthcare access, food assistance use, and transportation availability relate to overall well-being across counties in North Carolina?

# %%
scatterplot = sns.scatterplot(
    data=df,
    x='B08006_008E',
    y='B09010_002E'
)
